# %% [markdown]
# ## María Paula Calderón Jaimes
# - Link LinkedIn: https://www.linkedin.com/in/mar%C3%ADa-paula-calder%C3%B3n-jaimes-321259231/
# - Certificados:

# %% [markdown]
# # Python 101 for Dtaa Science
#
# ![macalderonjcognitiveclasspython101.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Data Visualization with Python
# ![macalderonjcognitiveclassdatavisualization.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Data Analysis with Python
#
# ![macalderonjcognitiveclassdataanalysis.jpg](data:image/jpeg;base64,...)
